# %%
## DATASET : HEART DISEASE DATASET
# 1.Split dataset into train and test sets.
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv("heart.csv")
x=df.drop("target",axis=1)
y=df["target"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print("Training set size :",x_train.shape)
print("Testing set size :",x_test.shape)
# Out:
# Training set size : (820, 13)
# Testing set size : (205, 13)

# %%
# 2.Explain purpose of training vs testing.
Training data helps the model learn relationships between features and target.

Testing data checks how well the model generalizes to new, unseen patients.

Prevents overfitting (memorizing data instead of learning patterns).

# %%
# 3.Train a simple model (Logistic Regression).
from sklearn.linear_model import LogisticRegression
model=LogisticRegression(max_iter=1000)
model.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# 4.Predict on test data.
y_pred=model.predict(x_test)

# %%
# 5.Calculate accuracy, precision, recall.
from sklearn.metrics import accuracy_score,precision_score,recall_score
accuracy=accuracy_score(y_test,y_pred)
precision=precision_score(y_test,y_pred)
recall=recall_score(y_test,y_pred)
print("Accuracy :",accuracy)
print("Precision :",precision)
print("Recall :",recall)
# Out:
# Accuracy : 0.7951219512195122
# Precision : 0.7563025210084033
# Recall : 0.8737864077669902

# %%
# 6.Explain confusion matrix.
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
cm=confusion_matrix(y_test,y_pred)
disp=ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
